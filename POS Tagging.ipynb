# %% [markdown]
# # **Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy). Analyze the grammatical structure of sentences using syntactic/dependency parsing.**

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = """Uttarakhand's history dates back to prehistoric times with archaeological evidence showcasing human habitation. It was part of the ancient Kuru and the Panchal kingdoms during the Vedic age and later saw the rise of dynasties like the Kunindas and influence of Buddhism as evidenced by Ashokan edicts.
Though primarily driven by agriculture and hydropower the state's economy is now dominated by the service industry. The service sector comprises primarily travel, tourism, and hotel industry.  The state contributes five seats to the lower house Lok Sabha and three seats to the upper house Rajya Sabha.Inhabitants of the state are called either Garhwali or Kumaoni depending on their region of origin. Hinduism is practiced by more than three-fourths of the population with Islam being the next-largest religious group. Hindi is the most widely spoken language and is also the official language of the state, along with native regional languages include Garhwali, Jaunsari, Gurjari and Kumaoni. The state is often referred to as the Devabhumi lit. Land of the Gods due to its religious significance and numerous Hindu temples and pilgrimage centres found throughout the state.Along with several historical, natural and religious tourist destinations, including Char Dham, Haridwar, Rishikesh, Panch Kedar, Himalayas, and Sapta Badri. Uttarakhand is also home to two World Heritage sites.
"""

# %%
doc=nlp(text)

# %% [markdown]
# #POS tagging

# %%
for token in doc:
    print(f"{token.text:15}  POS: {token.pos_:10}  TAG: {token.tag_:10}  DEP: {token.dep_}  Description: {spacy.explain(token.tag_)}")
# Out:
# Uttarakhand      POS: PROPN       TAG: NNP         DEP: poss  Description: noun, proper singular
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# history          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# dates            POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# back             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# prehistoric      POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# times            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# archaeological   POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# evidence         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# showcasing       POS: VERB        TAG: VBG         DEP: acl  Description: verb, gerund or present participle
# human            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# habitation       POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# It               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# was              POS: AUX         TAG: VBD         DEP: ROOT  Description: verb, past tense
# part             POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# ancient          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# Kuru             POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Panchal          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# kingdoms         POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# during           POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Vedic            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# age              POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# later            POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# saw              POS: VERB        TAG: VBD         DEP: conj  Description: verb, past tense
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# rise             POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# dynasties        POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# like             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Kunindas         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# influence        POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Buddhism         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# as               POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# evidenced        POS: VERB        TAG: VBN         DEP: advcl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# Ashokan          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# edicts           POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Though           POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# primarily        POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# driven           POS: VERB        TAG: VBN         DEP: advcl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# agriculture      POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# hydropower       POS: VERB        TAG: VB          DEP: conj  Description: verb, base form
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# state            POS: NOUN        TAG: NN          DEP: poss  Description: noun, singular or mass
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# economy          POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: auxpass  Description: verb, 3rd person singular present
# now              POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# dominated        POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# service          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# industry         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# service          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# sector           POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# comprises        POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# primarily        POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# travel           POS: VERB        TAG: VBP         DEP: dobj  Description: verb, non-3rd person singular present
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# tourism          POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# hotel            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# industry         POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#                  POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# state            POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# contributes      POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# five             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# seats            POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# lower            POS: ADJ         TAG: JJR         DEP: amod  Description: adjective, comparative
# house            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# Lok              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Sabha            POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# three            POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# seats            POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# upper            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# house            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# Rajya            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Sabha            POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Inhabitants      POS: NOUN        TAG: NNS         DEP: nsubjpass  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# state            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# are              POS: AUX         TAG: VBP         DEP: auxpass  Description: verb, non-3rd person singular present
# called           POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# either           POS: CCONJ       TAG: CC          DEP: preconj  Description: conjunction, coordinating
# Garhwali         POS: PROPN       TAG: NNP         DEP: oprd  Description: noun, proper singular
# or               POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Kumaoni          POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# depending        POS: VERB        TAG: VBG         DEP: prep  Description: verb, gerund or present participle
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# their            POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# region           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# origin           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Hinduism         POS: PROPN       TAG: NNP         DEP: nsubjpass  Description: noun, proper singular
# is               POS: AUX         TAG: VBZ         DEP: auxpass  Description: verb, 3rd person singular present
# practiced        POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# more             POS: ADJ         TAG: JJR         DEP: amod  Description: adjective, comparative
# than             POS: ADP         TAG: IN          DEP: quantmod  Description: conjunction, subordinating or preposition
# three            POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# fourths          POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# population       POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Islam            POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# being            POS: AUX         TAG: VBG         DEP: pcomp  Description: verb, gerund or present participle
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# next             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# largest          POS: ADJ         TAG: JJS         DEP: amod  Description: adjective, superlative
# religious        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# group            POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Hindi            POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# most             POS: ADV         TAG: RBS         DEP: advmod  Description: adverb, superlative
# widely           POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# spoken           POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# language         POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# is               POS: AUX         TAG: VBZ         DEP: conj  Description: verb, 3rd person singular present
# also             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# official         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# language         POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# state            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# along            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# native           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# regional         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# languages        POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# include          POS: VERB        TAG: VBP         DEP: ccomp  Description: verb, non-3rd person singular present
# Garhwali         POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Jaunsari         POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Gurjari          POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Kumaoni          POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# state            POS: NOUN        TAG: NN          DEP: nsubjpass  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: auxpass  Description: verb, 3rd person singular present
# often            POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# referred         POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Devabhumi        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# lit              POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#                  POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Land             POS: PROPN       TAG: NNP         DEP: ROOT  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Gods             POS: PROPN       TAG: NNPS        DEP: pobj  Description: noun, proper plural
# due              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# to               POS: ADP         TAG: IN          DEP: pcomp  Description: conjunction, subordinating or preposition
# its              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# religious        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# significance     POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# numerous         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# Hindu            POS: ADJ         TAG: JJ          DEP: compound  Description: adjective (English), other noun-modifier (Chinese)
# temples          POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# pilgrimage       POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# centres          POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# found            POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# throughout       POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# state            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Along            POS: ADP         TAG: IN          DEP: ROOT  Description: conjunction, subordinating or preposition
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# several          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# historical       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# natural          POS: ADJ         TAG: JJ          DEP: conj  Description: adjective (English), other noun-modifier (Chinese)
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# religious        POS: ADJ         TAG: JJ          DEP: conj  Description: adjective (English), other noun-modifier (Chinese)
# tourist          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# destinations     POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# including        POS: VERB        TAG: VBG         DEP: prep  Description: verb, gerund or present participle
# Char             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Dham             POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Haridwar         POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Rishikesh        POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Panch            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Kedar            POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Himalayas        POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Sapta            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Badri            POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Uttarakhand      POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# also             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# home             POS: ADV         TAG: RB          DEP: acomp  Description: adverb
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# two              POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# World            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Heritage         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# sites            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace

# %% [markdown]
# #Dependency Parsing

# %%
for token in doc:
    print(f"{token.text:12} <--{token.dep_:10}-- {token.head.text}")
# Out:
# Uttarakhand  <--poss      -- history
# 's           <--case      -- Uttarakhand
# history      <--nsubj     -- dates
# dates        <--ROOT      -- dates
# back         <--advmod    -- dates
# to           <--prep      -- back
# prehistoric  <--amod      -- times
# times        <--pobj      -- to
# with         <--prep      -- dates
# archaeological <--amod      -- evidence
# evidence     <--pobj      -- with
# showcasing   <--acl       -- evidence
# human        <--amod      -- habitation
# habitation   <--dobj      -- showcasing
# .            <--punct     -- dates
# It           <--nsubj     -- was
# was          <--ROOT      -- was
# part         <--attr      -- was
# of           <--prep      -- part
# the          <--det       -- Kuru
# ancient      <--amod      -- Kuru
# Kuru         <--pobj      -- of
# and          <--cc        -- Kuru
# the          <--det       -- kingdoms
# Panchal      <--compound  -- kingdoms
# kingdoms     <--conj      -- Kuru
# during       <--prep      -- was
# the          <--det       -- age
# Vedic        <--compound  -- age
# age          <--pobj      -- during
# and          <--cc        -- was
# later        <--advmod    -- saw
# saw          <--conj      -- was
# the          <--det       -- rise
# rise         <--dobj      -- saw
# of           <--prep      -- rise
# dynasties    <--pobj      -- of
# like         <--prep      -- dynasties
# the          <--det       -- Kunindas
# Kunindas     <--pobj      -- like
# and          <--cc        -- Kunindas
# influence    <--conj      -- Kunindas
# of           <--prep      -- influence
# Buddhism     <--pobj      -- of
# as           <--mark      -- evidenced
# evidenced    <--advcl     -- rise
# by           <--agent     -- evidenced
# Ashokan      <--amod      -- edicts
# edicts       <--pobj      -- by
# .            <--punct     -- was
# Though       <--mark      -- driven
# primarily    <--advmod    -- driven
# driven       <--advcl     -- dominated
# by           <--agent     -- driven
# agriculture  <--pobj      -- by
# and          <--cc        -- driven
# hydropower   <--conj      -- driven
# the          <--det       -- state
# state        <--poss      -- economy
# 's           <--case      -- state
# economy      <--dobj      -- hydropower
# is           <--auxpass   -- dominated
# now          <--advmod    -- dominated
# dominated    <--ROOT      -- dominated
# by           <--agent     -- dominated
# the          <--det       -- industry
# service      <--compound  -- industry
# industry     <--pobj      -- by
# .            <--punct     -- dominated
# The          <--det       -- sector
# service      <--compound  -- sector
# sector       <--nsubj     -- comprises
# comprises    <--ROOT      -- comprises
# primarily    <--advmod    -- travel
# travel       <--dobj      -- comprises
# ,            <--punct     -- travel
# tourism      <--conj      -- travel
# ,            <--punct     -- tourism
# and          <--cc        -- tourism
# hotel        <--compound  -- industry
# industry     <--conj      -- tourism
# .            <--punct     -- comprises
#              <--dep       -- .
# The          <--det       -- state
# state        <--nsubj     -- contributes
# contributes  <--ROOT      -- contributes
# five         <--nummod    -- seats
# seats        <--dobj      -- contributes
# to           <--prep      -- seats
# the          <--det       -- house
# lower        <--amod      -- house
# house        <--pobj      -- to
# Lok          <--compound  -- Sabha
# Sabha        <--appos     -- house
# and          <--cc        -- seats
# three        <--nummod    -- seats
# seats        <--conj      -- seats
# to           <--prep      -- seats
# the          <--det       -- house
# upper        <--amod      -- house
# house        <--pobj      -- to
# Rajya        <--compound  -- Sabha
# Sabha        <--appos     -- house
# .            <--punct     -- contributes
# Inhabitants  <--nsubjpass -- called
# of           <--prep      -- Inhabitants
# the          <--det       -- state
# state        <--pobj      -- of
# are          <--auxpass   -- called
# called       <--ROOT      -- called
# either       <--preconj   -- Garhwali
# Garhwali     <--oprd      -- called
# or           <--cc        -- Garhwali
# Kumaoni      <--conj      -- Garhwali
# depending    <--prep      -- called
# on           <--prep      -- depending
# their        <--poss      -- region
# region       <--pobj      -- on
# of           <--prep      -- region
# origin       <--pobj      -- of
# .            <--punct     -- called
# Hinduism     <--nsubjpass -- practiced
# is           <--auxpass   -- practiced
# practiced    <--ROOT      -- practiced
# by           <--agent     -- practiced
# more         <--amod      -- three
# than         <--quantmod  -- three
# three        <--nummod    -- fourths
# -            <--punct     -- fourths
# fourths      <--pobj      -- by
# of           <--prep      -- fourths
# the          <--det       -- population
# population   <--pobj      -- of
# with         <--prep      -- population
# Islam        <--nsubj     -- being
# being        <--pcomp     -- with
# the          <--det       -- group
# next         <--advmod    -- largest
# -            <--punct     -- largest
# largest      <--amod      -- group
# religious    <--amod      -- group
# group        <--attr      -- being
# .            <--punct     -- practiced
# Hindi        <--nsubj     -- is
# is           <--ROOT      -- is
# the          <--det       -- language
# most         <--advmod    -- widely
# widely       <--advmod    -- spoken
# spoken       <--amod      -- language
# language     <--attr      -- is
# and          <--cc        -- is
# is           <--conj      -- is
# also         <--advmod    -- is
# the          <--det       -- language
# official     <--amod      -- language
# language     <--attr      -- is
# of           <--prep      -- language
# the          <--det       -- state
# state        <--pobj      -- of
# ,            <--punct     -- is
# along        <--prep      -- is
# with         <--prep      -- along
# native       <--amod      -- languages
# regional     <--amod      -- languages
# languages    <--pobj      -- with
# include      <--ccomp     -- is
# Garhwali     <--dobj      -- include
# ,            <--punct     -- Garhwali
# Jaunsari     <--conj      -- Garhwali
# ,            <--punct     -- Jaunsari
# Gurjari      <--conj      -- Jaunsari
# and          <--cc        -- Gurjari
# Kumaoni      <--conj      -- Gurjari
# .            <--punct     -- is
# The          <--det       -- state
# state        <--nsubjpass -- referred
# is           <--auxpass   -- referred
# often        <--advmod    -- referred
# referred     <--ROOT      -- referred
# to           <--prep      -- referred
# as           <--prep      -- referred
# the          <--det       -- lit
# Devabhumi    <--compound  -- lit
# lit          <--pobj      -- as
# .            <--punct     -- referred
#              <--dep       -- .
# Land         <--ROOT      -- Land
# of           <--prep      -- Land
# the          <--det       -- Gods
# Gods         <--pobj      -- of
# due          <--prep      -- Land
# to           <--pcomp     -- due
# its          <--poss      -- significance
# religious    <--amod      -- significance
# significance <--pobj      -- due
# and          <--cc        -- significance
# numerous     <--amod      -- temples
# Hindu        <--compound  -- temples
# temples      <--conj      -- significance
# and          <--cc        -- temples
# pilgrimage   <--compound  -- centres
# centres      <--conj      -- temples
# found        <--acl       -- Land
# throughout   <--prep      -- found
# the          <--det       -- state
# state        <--pobj      -- throughout
# .            <--punct     -- Land
# Along        <--ROOT      -- Along
# with         <--prep      -- Along
# several      <--amod      -- destinations
# historical   <--amod      -- destinations
# ,            <--punct     -- historical
# natural      <--conj      -- historical
# and          <--cc        -- natural
# religious    <--conj      -- natural
# tourist      <--compound  -- destinations
# destinations <--pobj      -- with
# ,            <--punct     -- destinations
# including    <--prep      -- destinations
# Char         <--compound  -- Dham
# Dham         <--pobj      -- including
# ,            <--punct     -- Dham
# Haridwar     <--conj      -- Dham
# ,            <--punct     -- Haridwar
# Rishikesh    <--conj      -- Haridwar
# ,            <--punct     -- Rishikesh
# Panch        <--compound  -- Kedar
# Kedar        <--conj      -- Rishikesh
# ,            <--punct     -- Kedar
# Himalayas    <--conj      -- Kedar
# ,            <--punct     -- Himalayas
# and          <--cc        -- Himalayas
# Sapta        <--compound  -- Badri
# Badri        <--conj      -- Himalayas
# .            <--punct     -- Along
# Uttarakhand  <--nsubj     -- is
# is           <--ROOT      -- is
# also         <--advmod    -- is
# home         <--acomp     -- is
# to           <--prep      -- home
# two          <--nummod    -- sites
# World        <--compound  -- Heritage
# Heritage     <--compound  -- sites
# sites        <--pobj      -- to
# .            <--punct     -- is
#
#             <--dep       -- .

# %% [markdown]
# #Sentence wise grammar parsing

# %%
for sent in doc.sents:
    print("Sentence:", sent.text)
    for token in sent:
        print(f"  {token.text:15} {token.pos_:10} {token.dep_:10} --> {token.head.text}")
    print()
# Out:
# Sentence: Uttarakhand's history dates back to prehistoric times with archaeological evidence showcasing human habitation.
#   Uttarakhand     PROPN      poss       --> history
#   's              PART       case       --> Uttarakhand
#   history         NOUN       nsubj      --> dates
#   dates           VERB       ROOT       --> dates
#   back            ADV        advmod     --> dates
#   to              ADP        prep       --> back
#   prehistoric     ADJ        amod       --> times
#   times           NOUN       pobj       --> to
#   with            ADP        prep       --> dates
#   archaeological  ADJ        amod       --> evidence
#   evidence        NOUN       pobj       --> with
#   showcasing      VERB       acl        --> evidence
#   human           ADJ        amod       --> habitation
#   habitation      NOUN       dobj       --> showcasing
#   .               PUNCT      punct      --> dates
#
# Sentence: It was part of the ancient Kuru and the Panchal kingdoms during the Vedic age and later saw the rise of dynasties like the Kunindas and influence of Buddhism as evidenced by Ashokan edicts.
#   It              PRON       nsubj      --> was
#   was             AUX        ROOT       --> was
#   part            NOUN       attr       --> was
#   of              ADP        prep       --> part
#   the             DET        det        --> Kuru
#   ancient         ADJ        amod       --> Kuru
#   Kuru            PROPN      pobj       --> of
#   and             CCONJ      cc         --> Kuru
#   the             DET        det        --> kingdoms
#   Panchal         PROPN      compound   --> kingdoms
#   kingdoms        NOUN       conj       --> Kuru
#   during          ADP        prep       --> was
#   the             DET        det        --> age
#   Vedic           PROPN      compound   --> age
#   age             NOUN       pobj       --> during
#   and             CCONJ      cc         --> was
#   later           ADV        advmod     --> saw
#   saw             VERB       conj       --> was
#   the             DET        det        --> rise
#   rise            NOUN       dobj       --> saw
#   of              ADP        prep       --> rise
#   dynasties       NOUN       pobj       --> of
#   like            ADP        prep       --> dynasties
#   the             DET        det        --> Kunindas
#   Kunindas        PROPN      pobj       --> like
#   and             CCONJ      cc         --> Kunindas
#   influence       NOUN       conj       --> Kunindas
#   of              ADP        prep       --> influence
#   Buddhism        PROPN      pobj       --> of
#   as              SCONJ      mark       --> evidenced
#   evidenced       VERB       advcl      --> rise
#   by              ADP        agent      --> evidenced
#   Ashokan         ADJ        amod       --> edicts
#   edicts          NOUN       pobj       --> by
#   .               PUNCT      punct      --> was
#
# Sentence: Though primarily driven by agriculture and hydropower the state's economy is now dominated by the service industry.
#   Though          SCONJ      mark       --> driven
#   primarily       ADV        advmod     --> driven
#   driven          VERB       advcl      --> dominated
#   by              ADP        agent      --> driven
#   agriculture     NOUN       pobj       --> by
#   and             CCONJ      cc         --> driven
#   hydropower      VERB       conj       --> driven
#   the             DET        det        --> state
#   state           NOUN       poss       --> economy
#   's              PART       case       --> state
#   economy         NOUN       dobj       --> hydropower
#   is              AUX        auxpass    --> dominated
#   now             ADV        advmod     --> dominated
#   dominated       VERB       ROOT       --> dominated
#   by              ADP        agent      --> dominated
#   the             DET        det        --> industry
#   service         NOUN       compound   --> industry
#   industry        NOUN       pobj       --> by
#   .               PUNCT      punct      --> dominated
#
# Sentence: The service sector comprises primarily travel, tourism, and hotel industry.
#   The             DET        det        --> sector
#   service         NOUN       compound   --> sector
#   sector          NOUN       nsubj      --> comprises
#   comprises       VERB       ROOT       --> comprises
#   primarily       ADV        advmod     --> travel
#   travel          VERB       dobj       --> comprises
#   ,               PUNCT      punct      --> travel
#   tourism         NOUN       conj       --> travel
#   ,               PUNCT      punct      --> tourism
#   and             CCONJ      cc         --> tourism
#   hotel           NOUN       compound   --> industry
#   industry        NOUN       conj       --> tourism
#   .               PUNCT      punct      --> comprises
#                   SPACE      dep        --> .
#
# Sentence: The state contributes five seats to the lower house Lok Sabha and three seats to the upper house Rajya Sabha.
#   The             DET        det        --> state
#   state           NOUN       nsubj      --> contributes
#   contributes     VERB       ROOT       --> contributes
#   five            NUM        nummod     --> seats
#   seats           NOUN       dobj       --> contributes
#   to              ADP        prep       --> seats
#   the             DET        det        --> house
#   lower           ADJ        amod       --> house
#   house           NOUN       pobj       --> to
#   Lok             PROPN      compound   --> Sabha
#   Sabha           PROPN      appos      --> house
#   and             CCONJ      cc         --> seats
#   three           NUM        nummod     --> seats
#   seats           NOUN       conj       --> seats
#   to              ADP        prep       --> seats
#   the             DET        det        --> house
#   upper           ADJ        amod       --> house
#   house           NOUN       pobj       --> to
#   Rajya           PROPN      compound   --> Sabha
#   Sabha           PROPN      appos      --> house
#   .               PUNCT      punct      --> contributes
#
# Sentence: Inhabitants of the state are called either Garhwali or Kumaoni depending on their region of origin.
#   Inhabitants     NOUN       nsubjpass  --> called
#   of              ADP        prep       --> Inhabitants
#   the             DET        det        --> state
#   state           NOUN       pobj       --> of
#   are             AUX        auxpass    --> called
#   called          VERB       ROOT       --> called
#   either          CCONJ      preconj    --> Garhwali
#   Garhwali        PROPN      oprd       --> called
#   or              CCONJ      cc         --> Garhwali
#   Kumaoni         PROPN      conj       --> Garhwali
#   depending       VERB       prep       --> called
#   on              ADP        prep       --> depending
#   their           PRON       poss       --> region
#   region          NOUN       pobj       --> on
#   of              ADP        prep       --> region
#   origin          NOUN       pobj       --> of
#   .               PUNCT      punct      --> called
#
# Sentence: Hinduism is practiced by more than three-fourths of the population with Islam being the next-largest religious group.
#   Hinduism        PROPN      nsubjpass  --> practiced
#   is              AUX        auxpass    --> practiced
#   practiced       VERB       ROOT       --> practiced
#   by              ADP        agent      --> practiced
#   more            ADJ        amod       --> three
#   than            ADP        quantmod   --> three
#   three           NUM        nummod     --> fourths
#   -               PUNCT      punct      --> fourths
#   fourths         NOUN       pobj       --> by
#   of              ADP        prep       --> fourths
#   the             DET        det        --> population
#   population      NOUN       pobj       --> of
#   with            ADP        prep       --> population
#   Islam           PROPN      nsubj      --> being
#   being           AUX        pcomp      --> with
#   the             DET        det        --> group
#   next            ADV        advmod     --> largest
#   -               PUNCT      punct      --> largest
#   largest         ADJ        amod       --> group
#   religious       ADJ        amod       --> group
#   group           NOUN       attr       --> being
#   .               PUNCT      punct      --> practiced
#
# Sentence: Hindi is the most widely spoken language and is also the official language of the state, along with native regional languages include Garhwali, Jaunsari, Gurjari and Kumaoni.
#   Hindi           PROPN      nsubj      --> is
#   is              AUX        ROOT       --> is
#   the             DET        det        --> language
#   most            ADV        advmod     --> widely
#   widely          ADV        advmod     --> spoken
#   spoken          VERB       amod       --> language
#   language        NOUN       attr       --> is
#   and             CCONJ      cc         --> is
#   is              AUX        conj       --> is
#   also            ADV        advmod     --> is
#   the             DET        det        --> language
#   official        ADJ        amod       --> language
#   language        NOUN       attr       --> is
#   of              ADP        prep       --> language
#   the             DET        det        --> state
#   state           NOUN       pobj       --> of
#   ,               PUNCT      punct      --> is
#   along           ADP        prep       --> is
#   with            ADP        prep       --> along
#   native          ADJ        amod       --> languages
#   regional        ADJ        amod       --> languages
#   languages       NOUN       pobj       --> with
#   include         VERB       ccomp      --> is
#   Garhwali        PROPN      dobj       --> include
#   ,               PUNCT      punct      --> Garhwali
#   Jaunsari        PROPN      conj       --> Garhwali
#   ,               PUNCT      punct      --> Jaunsari
#   Gurjari         PROPN      conj       --> Jaunsari
#   and             CCONJ      cc         --> Gurjari
#   Kumaoni         PROPN      conj       --> Gurjari
#   .               PUNCT      punct      --> is
#
# Sentence: The state is often referred to as the Devabhumi lit.
#   The             DET        det        --> state
#   state           NOUN       nsubjpass  --> referred
#   is              AUX        auxpass    --> referred
#   often           ADV        advmod     --> referred
#   referred        VERB       ROOT       --> referred
#   to              ADP        prep       --> referred
#   as              ADP        prep       --> referred
#   the             DET        det        --> lit
#   Devabhumi       PROPN      compound   --> lit
#   lit             NOUN       pobj       --> as
#   .               PUNCT      punct      --> referred
#                   SPACE      dep        --> .
#
# Sentence: Land of the Gods due to its religious significance and numerous Hindu temples and pilgrimage centres found throughout the state.
#   Land            PROPN      ROOT       --> Land
#   of              ADP        prep       --> Land
#   the             DET        det        --> Gods
#   Gods            PROPN      pobj       --> of
#   due             ADP        prep       --> Land
#   to              ADP        pcomp      --> due
#   its             PRON       poss       --> significance
#   religious       ADJ        amod       --> significance
#   significance    NOUN       pobj       --> due
#   and             CCONJ      cc         --> significance
#   numerous        ADJ        amod       --> temples
#   Hindu           ADJ        compound   --> temples
#   temples         NOUN       conj       --> significance
#   and             CCONJ      cc         --> temples
#   pilgrimage      NOUN       compound   --> centres
#   centres         NOUN       conj       --> temples
#   found           VERB       acl        --> Land
#   throughout      ADP        prep       --> found
#   the             DET        det        --> state
#   state           NOUN       pobj       --> throughout
#   .               PUNCT      punct      --> Land
#
# Sentence: Along with several historical, natural and religious tourist destinations, including Char Dham, Haridwar, Rishikesh, Panch Kedar, Himalayas, and Sapta Badri.
#   Along           ADP        ROOT       --> Along
#   with            ADP        prep       --> Along
#   several         ADJ        amod       --> destinations
#   historical      ADJ        amod       --> destinations
#   ,               PUNCT      punct      --> historical
#   natural         ADJ        conj       --> historical
#   and             CCONJ      cc         --> natural
#   religious       ADJ        conj       --> natural
#   tourist         NOUN       compound   --> destinations
#   destinations    NOUN       pobj       --> with
#   ,               PUNCT      punct      --> destinations
#   including       VERB       prep       --> destinations
#   Char            PROPN      compound   --> Dham
#   Dham            PROPN      pobj       --> including
#   ,               PUNCT      punct      --> Dham
#   Haridwar        PROPN      conj       --> Dham
#   ,               PUNCT      punct      --> Haridwar
#   Rishikesh       PROPN      conj       --> Haridwar
#   ,               PUNCT      punct      --> Rishikesh
#   Panch           PROPN      compound   --> Kedar
#   Kedar           PROPN      conj       --> Rishikesh
#   ,               PUNCT      punct      --> Kedar
#   Himalayas       PROPN      conj       --> Kedar
#   ,               PUNCT      punct      --> Himalayas
#   and             CCONJ      cc         --> Himalayas
#   Sapta           PROPN      compound   --> Badri
#   Badri           PROPN      conj       --> Himalayas
#   .               PUNCT      punct      --> Along
#
# Sentence: Uttarakhand is also home to two World Heritage sites.
#
#   Uttarakhand     PROPN      nsubj      --> is
#   is              AUX        ROOT       --> is
#   also            ADV        advmod     --> is
#   home            ADV        acomp      --> is
#   to              ADP        prep       --> home
#   two             NUM        nummod     --> sites
#   World           PROPN      compound   --> Heritage
#   Heritage        PROPN      compound   --> sites
#   sites           NOUN       pobj       --> to
#   .               PUNCT      punct      --> is
#
#                SPACE      dep        --> .

# %% [markdown]
# #Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="35b77c40d69543a4ab4a6de876c0d31b-0" class="displacy" width="38550" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Uttarakhand</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">history</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">dates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">back</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">prehistoric</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">times</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">archaeological</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">evidence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">showcasing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">human</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">habitation.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">part</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">ancient</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Kuru</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Panchal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">kingdoms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">during</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Vedic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">age</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">later</tspan>
#     <tspan class="displacy-tag" dy="
